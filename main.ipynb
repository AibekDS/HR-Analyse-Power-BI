# %%
import pandas as pd

# %%
df = pd.read_csv("Clustered HR Data\data.csv")

# %%
df
# Out:
#       Age Attrition BusinessTravel  DailyRate       Department  \
# 0      59        No     Non-Travel       1420  Human Resources
# 1      41        No     Non-Travel        552  Human Resources
# 2      38        No     Non-Travel       1336  Human Resources
# 3      28        No     Non-Travel        280  Human Resources
# 4      42        No     Non-Travel        179  Human Resources
# ...   ...       ...            ...        ...              ...
# 1465   40       Yes  Travel_Rarely        575            Sales
# 1466   40       Yes  Travel_Rarely        299            Sales
# 1467   50       Yes  Travel_Rarely        410            Sales
# 1468   34       Yes  Travel_Rarely        790            Sales
# 1469   19       Yes  Travel_Rarely        419            Sales
#
#      Distance from office  Education   EducationField  EmployeeCount  \
# 0              Very Closs          4  Human Resources              1
# ...

# %% [markdown]
# ## Set gender.csv

# %%
genDf = pd.DataFrame(['Male', 'Female'], index = [1, 2])

# %%
genDf.columns = ['gender']

# %%
genDf.index.name = 'gender_id'

# %%
genDf
# Out:
#            gender
# gender_id
# 1            Male
# 2          Female

# %%
genDf.to_csv("gender.csv")

# %%
for i in range(len(df)):
    if df.at[i, 'Gender'] == 'Male':
        df.at[i, 'Gender'] = 1
    else:
        df.at[i, 'Gender'] = 2

# %% [markdown]
# ## Set education.csv

# %%
df['Education'].unique()
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
e = ["Bachelor's Degree", "Master's Degree", "Doctoral Degree", "Post-Doctoral Studies", "Professional Degrees"]

# %%
eduDf = pd.DataFrame(e, index=[i for i in range(1, len(e)+1)])

# %%
eduDf.columns = ['education']

# %%
eduDf.index.name = "edu_id"

# %%
eduDf
# Out:
#                     education
# edu_id
# 1           Bachelor's Degree
# 2             Master's Degree
# 3             Doctoral Degree
# 4       Post-Doctoral Studies
# 5        Professional Degrees

# %%
eduDf.to_csv('education.csv')
